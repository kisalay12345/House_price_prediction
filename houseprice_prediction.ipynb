# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import os
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
def checkcsv():
    csv_files=[]
    cur_dir=os.getcwd()
    content_list=os.listdir(cur_dir)
    for x in content_list:
        if x.split('.')[-1]=='csv':
            csv_files.append(x)
    if len(csv_files)==0:
        return 'No csv file in the directory'
    else:
        return csv_files
def display_and_select_csv(csv_files):
    i=0
    for file_name in csv_files:
        print(i,'...',file_name)
        i+=1
    return csv_files[int(input("\nSelect file to create ML model\n"))]

# %%
csv_files=checkcsv()

if csv_files=='No csv file in the directory':
     sys.exit()
csv=display_and_select_csv(csv_files)
print("\nthe datafile is selected\n")
HouseDF=pd.read_csv(csv)
# Out:
# 0 ... famous-people.csv
# 1 ... gama.csv
# 2 ... housing.csv
# 3 ... mercedesbenz.csv
# 4 ... salary.csv
# 5 ... test.csv
# 6 ... USA_Housing.csv
#
# Select file to create ML model
# 6
#
# the datafile is selected

# %%
print('press enter to see the datafile\n')
input()
HouseDF.head()
# Out:
# press enter to see the datafile
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# ...

# %%
HouseDF.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
print("\npress enter to see data in graphical form\n")
input()
sns.pairplot(HouseDF)
sns.set()
# Out:
# press enter to see data in graphical form

# %%
print("\npress enter to see heatmap of data\n")
input()
sns.heatmap(HouseDF.corr(),annot=True)
sns.set()
# Out:
# press enter to see heatmap of data

# %%
X=HouseDF[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population']]
Y=HouseDF[['Price']]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1,random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
Im=LinearRegression()

# %%
Im.fit(X_train,Y_train)
print('\nour model has been created\n')
# Out:
# our model has been created

# %%
print("press enter to test our model")
input()
prediction=Im.predict(X_test)
print('\nthe prediction has been done\n')
# Out:
# press enter to test our model
#
#
# the prediction has been done

# %%
print('\npress enter to see scatter diagram of predicted value and actual values\n')
input()
plt.scatter(Y_test,prediction)
plt.show()
# Out:
# press enter to see scatter diagram of predicted value and actual values

# %%
l=len(X_test)

# %%
temp=Y_test.to_numpy()

# %%
print('\npress enter to print predicted and actual values\n\n')
input()
print('Predicted values                Actual values\n')
i=0
while i<l:
    print(prediction[i],'           ',temp[i])
    i+=1
# Out:
# press enter to print predicted and actual values
#
#
#
# Predicted values                Actual values
#
# [1257098.0968535]             [1251688.61570287]
# [822086.7621192]             [873048.31964236]
# [1739484.60206397]             [1696977.6628326]
# [973128.92697017]             [1063964.28787395]
# [993918.45735552]             [948788.27570945]
# [645734.60078781]             [730043.6450596]
# [1074412.81648648]             [1166925.14614882]
# [856463.98369069]             [705444.1167909]
# [1445048.633527]             [1499988.87952261]
# [1201847.71924816]             [1288199.15272917]
# [1454475.5180504]             [1441736.76083757]
# [1296582.9891015]             [1279681.15439659]
# [1736858.04511711]             [1754969.16194479]
# [1336694.59015474]             [1511653.4548035]
# [1386280.00636489]             [1441956.20193639]
# [1223122.34992053]             [1119992.61883545]
# [615840.78603573]             [727866.52516791]
# ...

# %%
print('\nprint enter to see performance of our model\n')
input()
p=Im.score(X_test,Y_test)
print("\nour model is %2.2f%% accurate"%(p*100))
# Out:
# print enter to see performance of our model
#
#
#
# our model is 92.50% accurate

# %%
print('now you can predict house value\n\n')
# Out:
# now you can predict house value

# %%
a=float(input('inter income (in thousands)\n'))
b=float(input("inter house age (in years)  \n"))
c=float(input('number of rooms   \n'))
d=float(input('number of bedrooms    \n'))
e=float(input('area population\n'))
data={'Avg. Area Income':a, 'Avg. Area House Age':b, 'Avg. Area Number of Rooms':c,
       'Avg. Area Number of Bedrooms':d,'Area Population':e}

m=pd.DataFrame(data,index=['0'])
# Out:
# inter income (in thousands)
# 67000
# inter house age (in years)
# 5
# number of rooms
# 7
# number of bedrooms
# 3
# area population
# 34000

# %%
x=Im.predict(m)

if(x<0):
    print("\nsorry no house available of such specification")
else:
      print('\nthe pridected value is ',x[0,0])
# Out:
# the pridected value is  1002602.7502098186

# %%
print('press enter to exit')
input()
exit()
# Out:
# press enter to exit
